# %% [markdown]
# <a href="https://colab.research.google.com/github/Janvi2808/Linear-Regression/blob/main/Assesment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import numpy as np

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('CarPrice.csv')
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
# df[(df.Fueltype == 'gas') & (df.Enginelocation == 'front')][:10]

# %%
df[(df.fueltype == 'gas') & (df.enginelocation == 'front') & (df.drivewheel == 'rwd') & (df.carbody == 'sedan')]
# Out:
#      car_ID  symboling                    CarName fueltype aspiration  \
# 10       11          2                   bmw 320i      gas        std
# 11       12          0                   bmw 320i      gas        std
# 12       13          0                     bmw x1      gas        std
# 13       14          0                     bmw x3      gas        std
# 14       15          1                     bmw z4      gas        std
# 15       16          0                     bmw x4      gas        std
# 16       17          0                     bmw x5      gas        std
# 17       18          0                     bmw x3      gas        std
# 43       44          0                 isuzu MU-X      gas        std
# 47       48          0                  jaguar xj      gas        std
# 48       49          0                  jaguar xf      gas        std
# 49       50          0                  jaguar xk      gas        std
# ...

# %%
df[(df.fueltype == 'gas') & (df.enginelocation == 'front') & (df.drivewheel == 'rwd') & (df.carbody == 'hatchback')]
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 46       47          2              isuzu D-Max       gas        std
# 55       56          3                 mazda 626      gas        std
# 56       57          3                 mazda glc      gas        std
# 57       58          3             mazda rx-7 gs      gas        std
# 58       59          3               mazda glc 4      gas        std
# 75       76          1            mercury cougar      gas      turbo
# 104     105          3              nissan teana      gas        std
# 105     106          3              nissan kicks      gas      turbo
# 106     107          1            nissan clipper      gas        std
# 124     125          3           plymouth duster      gas      turbo
# 125     126          3             porsche macan      gas        std
# 129     130          1           porsche cayenne      gas        std
# ...

# %%
df[(df.wheelbase == 109.1) & (df.cylindernumber == 'four')]
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 200   sedan        rwd          front      109.1      188.8      68.9
# 201   sedan        rwd          front      109.1      188.8      68.8
# 204   sedan        rwd          front      109.1      188.8      68.9
#
#      carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 200       55.5        2952        ohc           four         141       mpfi
# 201       55.5        3049        ohc           four         141       mpfi
# 204       55.5        3062        ohc           four         141       mpfi
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
df[(df.enginesize == 141) & (df.cylindernumber == 'four')]
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 194     195         -2  volvo 145e (sw)      gas        std       four
# 195     196         -1      volvo 144ea      gas        std       four
# 196     197         -2      volvo 244dl      gas        std       four
# 197     198         -1        volvo 245      gas        std       four
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 194   sedan        rwd          front      104.3      188.8      67.2
# 195   wagon        rwd          front      104.3      188.8      67.2
# 196   sedan        rwd          front      104.3      188.8      67.2
# 197   wagon        rwd          front      104.3      188.8      67.2
# ...

# %%
df3 = df[['car_ID','symboling','wheelbase','carlength','carwidth','carheight','curbweight','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg','price']]
df3
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
df2 = df[['fueltype','aspiration','doornumber','carbody','enginelocation','cylindernumber']]
df2
# Out:
#     fueltype aspiration doornumber      carbody enginelocation cylindernumber
# 0        gas        std        two  convertible          front           four
# 1        gas        std        two  convertible          front           four
# 2        gas        std        two    hatchback          front            six
# 3        gas        std       four        sedan          front           four
# 4        gas        std       four        sedan          front           five
# ..       ...        ...        ...          ...            ...            ...
# 200      gas        std       four        sedan          front           four
# 201      gas      turbo       four        sedan          front           four
# 202      gas        std       four        sedan          front            six
# 203   diesel      turbo       four        sedan          front            six
# 204      gas      turbo       four        sedan          front           four
#
# [205 rows x 6 columns]

# %%
plt = sns.displot(df2['fueltype'], color ='purple')
sn.set(style='dark',)
data = np.random.randn(500)

# %%
plt = sns.displot(df2['doornumber'], color = 'purple')
sn.set(style='dark',)

# %%
sn.set(style='dark',)

# %%
sns.displot(df2['carbody'],color = 'purple')
data = np.random.randn(500)

# %%
import seaborn as sn
sn.set(style='dark',)

# %%
plt = sns.displot(df2['cylindernumber'],color = 'purple')

# %%
sns.kdeplot(df['price'], color = 'purple')
sn.set(style='dark',)
data = np.random.randn(500)

# %%
plt = sns.kdeplot(df['horsepower'],color = 'purple')
sn.set(style='dark',)
sn.set(style='dark',)
data = np.random.randn(500)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...
