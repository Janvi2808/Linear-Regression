# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("/content/commonwealth_games_2022.csv")

# %%
data
# Out:
#     pos                team  gold  silver  bronze  total
# 0     1           Australia    67      57      54    178
# 1     2             England    57      66      53    176
# 2     3              Canada    26      32      34     92
# 3     4               India    22      16      23     61
# 4     5         New Zealand    20      12      17     49
# 5     6            Scotland    13      11      27     51
# 6     7             Nigeria    12       9      14     35
# 7     8               Wales     8       6      14     28
# 8     9        South Africa     7       9      11     27
# 9    10            Malaysia     7       8       8     23
# 10   11    Northern Ireland     7       7       4     18
# 11   12             Jamaica     6       6       3     15
# 12   13               Kenya     6       5      10     21
# 13   14           Singapore     4       4       4     12
# 14   15   Trinidad & Tobago     3       2       1      6
# ...

# %%
data.head()
# Out:
#    pos         team  gold  silver  bronze  total
# 0    1    Australia    67      57      54    178
# 1    2      England    57      66      53    176
# 2    3       Canada    26      32      34     92
# 3    4        India    22      16      23     61
# 4    5  New Zealand    20      12      17     49

# %%
data1=data[data['total']>=1]
labels=data1['team']
y=data1['total']
colors=['Green']
fig = plt.figure(figsize =(15,10))#plt.bar(x, height, width, bottom, align)
plt.barh(labels,y,0.5,color=colors)
plt.show()

# %%
data1=data[data['gold']>=1]
labels=data1['team']
y=data1['gold']
colors=['gold']
fig = plt.figure(figsize =(15,10))
plt.barh(labels,y,0.5,color=colors)#plt.bar(x, height, width, bottom, align)
plt.show()

# %%
data1=data[data['silver']>=1]
labels=data1['team']
y=data1['silver']
colors=['silver']
fig = plt.figure(figsize =(15,10))
plt.barh(labels,y,0.5,color=colors)
plt.show()

# %%
data2=data[data['bronze']>=1]
labels=data2['team']
y=data2['bronze']
colors=['brown']
fig = plt.figure(figsize =(15,10))
plt.barh(labels,y,0.5,color=colors)
plt.show()

# %%
data['total'].value_counts().plot(kind="pie",labels=data['team'],autopct='%.2f',radius=2)
plt.show()
